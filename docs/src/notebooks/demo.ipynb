# %% [markdown]
# ## Titiler / STAC Demo
#
# This Notebook aims to show the different features provided by titiler application.
#
# First it will get a list of STAC Items available at a set of coordinates and display their boundaries on a map.
#
# Then it will print out the available assets and their information so we can chose which item and asset we want to view.
#
# After we select an item and asset, we will view it on a sample map using the information provided previously.
#
# You can view images based on pre-set search queries (ie query by STAC item metadata parameters such as collection, bounding box, acquisistion time, cloud cover, vendor, sensor, etc).
#
# Or you can view images based on STAC Item ID and Asset name.
#
# ### Python Requirements
# ```
# pip install httpx folium pypgstac psycopg psycopg-pool geojson-pydantic pandas
# ```

# %%
import json
import httpx
import pandas as pd
from folium import Map, TileLayer, GeoJson, raster_layers, LayerControl

from IPython.display import HTML, display

from geojson_pydantic import Feature, Polygon

endpoint = "https://gis.roycegeo.com/pgtitiler"

print(httpx.get(f"{endpoint}/healthz").json())
# Out:
# {'database_online': True, 'versions': {'titiler': '0.21.1', 'titiler.pgstac': '1.7.0', 'rasterio': '1.4.3', 'gdal': '3.9.3', 'proj': '9.4.1', 'geos': '3.11.1'}}

# %% [markdown]
# ### Show the bounding boxes of available Items at a set of coordinates on a map
#
# Using a path in the Collections group, were we supply the collection name (ares-demo) and a set of coordinates, titiler will return a list of STAC items at that location in the collection.
#
# We can use the geometry of each returned item to display on a map.

# %%
# Get the available Items at coordinates -63.403946,2.355549

bounds = (-63.58651954366129, 2.1766122457878, -63.25108334986687, 2.4148986049920276)
m = Map(
    tiles="OpenStreetMap",
    location=((bounds[1] + bounds[3]) / 2, (bounds[0] + bounds[2]) / 2),
    zoom_start=8,
)

response = httpx.get(
    f"{endpoint}/collections/ares-demo/point/-60.600332,3.968695/assets"
).json()

#  locations 
# -63.403946,2.355549
# -63.04044583,2.630686308
# -64.1718224,3.4175373
# -60.600332,3.968695
# -61.771634,5.955525

for item in response:
    bbox = item['bbox']
    poly = Polygon.from_bounds(bbox[0],bbox[1],bbox[2],bbox[3])
    geojson = Feature(type="Feature", geometry=poly, properties=None).model_dump(exclude_none=True)
    geo_json = GeoJson(
        data=geojson,
        style_function=lambda x: {
            "opacity": 1,
            "dashArray": "1",
            "fillOpacity": 0,
            "weight": 1,
            },
        )
    geo_json.add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_125fb7071a07ae06d286a4898c21d213 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_125fb7071a07ae06d286a4898c21d213&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_125fb7071a07ae06d286a4898c21d213 = L.map(
#                 &quot;map_125fb7071a07ae06d286a4898c21d213&quot;,
#                 {
#                     center: [2.2957554253899137, -63.41880144676408],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b026b69cb5d0cedca95d3bbabd8e0875 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b026b69cb5d0cedca95d3bbabd8e0875.addTo(map_125fb7071a07ae06d286a4898c21d213);
#
#
#         function geo_json_62f9ce6dddbcb2b738db4b195c07967e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;dashArray&quot;: &quot;1&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_62f9ce6dddbcb2b738db4b195c07967e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_62f9ce6dddbcb2b738db4b195c07967e = L.geoJson(null, {
#                 onEachFeature: geo_json_62f9ce6dddbcb2b738db4b195c07967e_onEachFeature,
#
#                 style: geo_json_62f9ce6dddbcb2b738db4b195c07967e_styler,
#             ...{
# }
#         });
#
#         function geo_json_62f9ce6dddbcb2b738db4b195c07967e_add (data) {
#             geo_json_62f9ce6dddbcb2b738db4b195c07967e
#                 .addData(data);
#         }
#             geo_json_62f9ce6dddbcb2b738db4b195c07967e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-60.837528204574305, 3.8374324930754], [-60.516156692030435, 3.8374324930754], [-60.516156692030435, 4.066150653867671], [-60.837528204574305, 4.066150653867671], [-60.837528204574305, 3.8374324930754]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_62f9ce6dddbcb2b738db4b195c07967e.addTo(map_125fb7071a07ae06d286a4898c21d213);
#
#
#         function geo_json_832fade6a3fb42e606c314c27dadfe4f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;dashArray&quot;: &quot;1&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_832fade6a3fb42e606c314c27dadfe4f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_832fade6a3fb42e606c314c27dadfe4f = L.geoJson(null, {
#                 onEachFeature: geo_json_832fade6a3fb42e606c314c27dadfe4f_onEachFeature,
#
#                 style: geo_json_832fade6a3fb42e606c314c27dadfe4f_styler,
#             ...{
# }
#         });
#
#         function geo_json_832fade6a3fb42e606c314c27dadfe4f_add (data) {
#             geo_json_832fade6a3fb42e606c314c27dadfe4f
#                 .addData(data);
#         }
#             geo_json_832fade6a3fb42e606c314c27dadfe4f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-60.7585539269397, 3.833438395098273], [-60.43826703339788, 3.833438395098273], [-60.43826703339788, 4.061685346704031], [-60.7585539269397, 4.061685346704031], [-60.7585539269397, 3.833438395098273]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_832fade6a3fb42e606c314c27dadfe4f.addTo(map_125fb7071a07ae06d286a4898c21d213);
#
#
#         function geo_json_305ae0a9af5ee87f24fe3f2d32ff71d9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;dashArray&quot;: &quot;1&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_305ae0a9af5ee87f24fe3f2d32ff71d9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_305ae0a9af5ee87f24fe3f2d32ff71d9 = L.geoJson(null, {
#                 onEachFeature: geo_json_305ae0a9af5ee87f24fe3f2d32ff71d9_onEachFeature,
#
#                 style: geo_json_305ae0a9af5ee87f24fe3f2d32ff71d9_styler,
#             ...{
# }
#         });
#
#         function geo_json_305ae0a9af5ee87f24fe3f2d32ff71d9_add (data) {
#             geo_json_305ae0a9af5ee87f24fe3f2d32ff71d9
#                 .addData(data);
#         }
#             geo_json_305ae0a9af5ee87f24fe3f2d32ff71d9_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-60.71882421405081, 3.824215855

# %% [markdown]
# ### View information about each STAC Item.
#
# We are displaying the about each STAC item returned.  We can use this information to create a query to sent to the Titiler api to display the image on a map.
#
# We need the item ID and asset name.  To make sure we are selecting the correct asset, we note the file type and url path.  In this project, we want to select Cloud Optimized Geotifs (COGSs) assets in the 'processed' directory.

# %%
print(f"Total Items at location: {len(response)}\n")

for item in response:
    print(f'Item ID: {item['id']}')
    print(item)
    for asset in item['assets']:
        print(f"    Asset Name: {asset}")
        print(f"    Asset URL: {item['assets'][asset]['href']}")
        print(f"    Asset File Type: {item['assets'][asset]['type']}")
        print("     ------------------------------------------------")
    print("\n")
# Out:
# Total Items at location: 12
#
# Item ID: 20250304_144759_59_24f8
# {'id': '20250304_144759_59_24f8', 'bbox': [-60.837528204574305, 3.8374324930754, -60.516156692030435, 4.066150653867671], 'assets': {'visual': {'href': 'gs://planet_labs_processed/20250304_144759_59_24f8_3B_Visual_reproject_file_format.tif', 'type': 'image/tiff; application=geotiff; profile=cloud-optimized', 'roles': ['data', 'visual'], 'eo:bands': [{'name': 'Red', 'common_name': 'red', 'center_wavelength': 0.665, 'full_width_half_max': 0.03}, {'name': 'Green', 'common_name': 'green', 'center_wavelength': 0.565, 'full_width_half_max': 0.036}, {'name': 'Blue', 'common_name': 'blue', 'center_wavelength': 0.49, 'full_width_half_max': 0.05}, {'name': 'Alpha', 'description': 'Pixel opacity (0: fully transparent; 255: fully opaque)'}], 'proj:bbox': [-60.837678944786155, 3.837322062638608, -60.51597234678328, 4.066251041262827], 'proj:epsg': 4326, 'proj:shape': [8466, 11897], 'raster:bands': [{'data_type': 'uint8', 'statistics': {'maximum': 255.0, 'minimum': 0.0}}, {'data_type': 'uint8', 'statistics': {'maximum': 255.0, 'minimum': 0.0}}, {'data_type': 'uint8', 'statistics': {'maximum': 255.0, 'minimum': 0.0}}, {'data_type': 'uint8', 'statistics': {'maximum': 255.0, 'minimum': 0.0}}], 'pl:asset_type': 'ortho_visual', 'pl:bundle_type': 'visual', 'proj:transform': [2.704098495443173e-05, 0.0, -60.837678944786155, 0.0, -2.704098495443173e-05, 4.066251041262827, 0.0, 0.0, 1.0]}, '20250304_144759_59_24f8_metadata_json': {'href': 'gs://planet_labs/01_jul/392f5509-824c-444a-ad20-7a002eb35ef6/PSScene/20250304_144759_59_24f8_metadata.json', 'type': 'application/json', 'roles': ['metadata']}, '20250304_144759_59_24f8_3B_Visual_reproject_file_format_tif': {'href': 'gs://planet_labs/01_jul/392f5509-824c-444a-ad20-7a002eb35ef6/PSScene/20250304_144759_59_24f8_3B_Visual_reproject_file_format.tif', 'type': 'image/tiff; application=geotiff; profile=cloud-optimized', 'roles': ['data', 'visual'], 'eo:bands': [{'name': 'Red', 'common_name': 'red', 'center_wavelength': 0.665, 'full_width_half_max': 0.03}, {'name': 'Green', 'common_name': 'green', 'center_wavelength': 0.565, 'full_width_half_max': 0.036}, {'name': 'Blue', 'common_name': 'blue', 'center_wavelength': 0.49, 'full_width_half_max': 0.05}, {'name': 'Alpha', 'description': 'Pixel opacity (0: fully transparent; 255: fully opaque)'}], 'proj:bbox': [-60
3B_Visual_reproject_file_format.tif
#     Asset File Type: image/tiff; application=geotiff; profile=cloud-optimized
#      ------------------------------------------------
#     Asset Name: 20241209_145318_27_24d6_metadata_json
#     Asset URL: gs://planet_labs/01_jul/5e53698b-7124-41b2-ba56-eb95732cb570/PSScene/20241209_145318_27_24d6_metadata.json
#     Asset File Type: application/json
#      ------------------------------------------------
#     Asset Name: 20241209_145318_27_24d6_3B_Visual_reproject_file_format_tif
#     Asset URL: gs://planet_labs/01_jul/5e53698b-7124-41b2-ba56-eb95732cb570/PSScene/20241209_145318_27_24d6_3B_Visual_reproject_file_format.tif
#     Asset File Type: image/tiff; application=geotiff; profile=cloud-optimized
#      ------------------------------------------------

# %% [markdown]
# ### View Image
#
# Titiler has several routes that will generate an image from a STAC item.  Generally, you will need the catalog name, item id, asset name and know the number of bands.
#
# For example, to use the Collections/Map Viewer route, we use the inputs from the information above to create a url that will return a map viewer.
#
# We want to create a sample map that shows the asset named 'visual' from the STAC ITEM 20250228_150538_15_2546 in the collection ares-demo
#
# gis.roycegeo.com/pgtitiler/collections/**COLLECITON**/items/**ITEM ID**/WebMercatorQuad/map?tile_scale=1&bidx=1&bidx=2&bidx=3&assets=**ASSET NAME**&asset_bidx=**ASSET NAME**%7C1%2C2%2C3
#
# "https://gis.roycegeo.com/pgtitiler/collections/ares-demo/items/20250228_150538_15_2546/WebMercatorQuad/map?tile_scale=1&bidx=1&bidx=2&bidx=3&assets=visual&asset_bidx=visual%7C1%2C2%2C3"

# %%
# %%html
# <iframe src="https://gis.roycegeo.com/pgtitiler/collections/ares-demo/items/20250304_144759_59_24f8/WebMercatorQuad/map?tile_scale=1&bidx=1&bidx=2&bidx=3&assets=visual&asset_bidx=visual%7C1%2C2%2C3" width="1200" height="1000"></iframe>
# Out:
# <iframe src="https://gis.roycegeo.com/pgtitiler/collections/ares-demo/items/20250304_144759_59_24f8/WebMercatorQuad/map?tile_scale=1&bidx=1&bidx=2&bidx=3&assets=visual&asset_bidx=visual%7C1%2C2%2C3" width="1200" height="1000"></iframe>

# %% [markdown]
# ### Register Search query
#
# Register a PGSTAC search query and return it's ID.  You can pre-set search queries generate dynamic tilers by search id.  Here, we will create a search for items in the ares demo, in a bounding box, taken within a specified date range.

# %%
# search_request = {
#     # Filter collection
#     "collections": ["ares-demo"],
#     # limit bounds of the known items (note: the bbox will also be used in the tilejson response)
#     "bbox": bounds,
# 	"datetime": "2024-11-28T01:01:01Z/2024-11-30T01:01:01Z",
#     "filter-lang": "cql-json",
# }

# response = httpx.post(
#     f"{endpoint}/searches/register",
#     json=search_request,
# ).json()
# print(response)

# searchid = response["id"]
searchid = "e1f9f3d794ac9669cf68e040e118cfbc"

# %% [markdown]
# ### Get Search Metadata

# %%
info_response = httpx.get(f"{endpoint}/searches/{searchid}/info").json()
print(json.dumps(info_response, indent=4))
# Out:
# {
#     "search": {
#         "hash": "e1f9f3d794ac9669cf68e040e118cfbc",
#         "search": {
#             "bbox": [
#                 -63.58651954366129,
#                 2.1766122457878,
#                 -63.25108334986687,
#                 2.4148986049920276
#             ],
#             "datetime": "2024-11-28T01:01:01Z/2024-11-30T01:01:01Z",
#             "collections": [
#                 "ares-demo"
#             ],
#             "filter-lang": "cql-json"
#         },
#         "_where": "collection = ANY ('{ares-demo}')  AND  datetime <= '2024-11-30 01:01:01+00'::timestamptz AND end_datetime >= '2024-11-28 01:01:01+00'::timestamptz  AND st_intersects(geometry, '0103000020E61000000100000005000000BB3E891213CB4FC08DDA5DAEB3690140BB3E891213CB4FC035C61C5CB6510340C91FCC7F23A04FC035C61C5CB6510340C91FCC7F23A04FC08DDA5DAEB3690140BB3E891213CB4FC08DDA5DAEB3690140')",
#         "orderby": "datetime DESC, id DESC",
#         "lastused": "2025-03-17T17:53:21.541131Z",
#         "usecount": 2,
#         "metadata": {
#             "type": "mosaic"
#         }
#     },
#     "links": [
#         {
#             "href": "https://gis.roycegeo.com/pgtitiler/searches/e1f9f3d794ac9669cf68e040e118cfbc/info",
#             "rel": "self",
#             "title": "Mosaic metadata"
#         },
#         {
#             "href": "https://gis.roycegeo.com/pgtitiler/searches/e1f9f3d794ac9669cf68e040e118cfbc/{tileMatrixSetId}/tilejson.json",
#             "rel": "tilejson",
#             "templated": true,
#             "title": "TileJSON link (Template URL)."
#         },
#         {
#             "href": "https://gis.roycegeo.com/pgtitiler/searches/e1f9f3d794ac9669cf68e040e118cfbc/{tileMatrixSetId}/map",
#             "rel": "map",
#             "templated": true,
#             "title": "Map viewer link (Template URL)."
#         },
#         {
#             "href": "https://gis.roycegeo.com/pgtitiler/searches/e1f9f3d794ac9669cf68e040e118cfbc/{tileMatrixSetId}/WMTSCapabilities.xml",
#             "rel": "wmts",
#             "templated": true,
#             "title": "WMTS link (Template URL)"
#         }
#     ]
# }

# %% [markdown]
# ### Get TileJSON
#
# Note: to return a valid tilejson document you'll need to pass either the `assets` or `expression` option.  Here we know that the name of the assets we want is 'visual.'

# %%
tj_response = httpx.get(
   f"{endpoint}/searches/{searchid}/WebMercatorQuad/tilejson.json?assets=visual"
).json()
# tj_response = httpx.get(
#     f"https://gis.roycegeo.com/pgtitiler/collections/ares-demo/items/20250228_150538_15_2546/WGS1984Quad/tilejson.json?bidx=1&bidx=2&bidx=3&assets=visual&asset_bidx=visual%7C1%2C2%2C3"
# ).json()

print(json.dumps(tj_response, indent=4))
# Out:
# {
#     "tilejson": "2.2.0",
#     "name": "e1f9f3d794ac9669cf68e040e118cfbc",
#     "version": "1.0.0",
#     "scheme": "xyz",
#     "tiles": [
#         "https://gis.roycegeo.com/pgtitiler/searches/e1f9f3d794ac9669cf68e040e118cfbc/tiles/WebMercatorQuad/{z}/{x}/{y}?assets=visual"
#     ],
#     "minzoom": 0,
#     "maxzoom": 24,
#     "bounds": [
#         -63.58651954366129,
#         2.1766122457878,
#         -63.25108334986687,
#         2.4148986049920276
#     ],
#     "center": [
#         -63.41880144676408,
#         2.2957554253899137,
#         0
#     ]
# }

# %% [markdown]
# ## Load tiles
#
# Use the TileJson create a layer on a map.

# %%
m = Map(
    location=((bounds[1] + bounds[3]) / 2, (bounds[0] + bounds[2]) / 2), zoom_start=14
)

geo_json = GeoJson(
    data=geojson,
    style_function=lambda x: {
        "opacity": 1,
        "dashArray": "1",
        "fillOpacity": 0,
        "weight": 1,
    },
)
geo_json.add_to(m)

aod_layer = TileLayer(
    tiles=tj_response["tiles"][0],
    attr="Mosaic",
    min_zoom=9,
    max_zoom=18,
    max_native_zoom=12,
)
aod_layer.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b8aa207e5709f68b88e6ef7ab68bf46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b8aa207e5709f68b88e6ef7ab68bf46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b8aa207e5709f68b88e6ef7ab68bf46 = L.map(
#                 &quot;map_1b8aa207e5709f68b88e6ef7ab68bf46&quot;,
#                 {
#                     center: [2.2957554253899137, -63.41880144676408],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c6140c068fe749b7a683cd93b6b90ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c6140c068fe749b7a683cd93b6b90ce.addTo(map_1b8aa207e5709f68b88e6ef7ab68bf46);
#
#
#         function geo_json_022ed812a3bd6515854956159571d9de_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;dashArray&quot;: &quot;1&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_022ed812a3bd6515854956159571d9de_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_022ed812a3bd6515854956159571d9de = L.geoJson(null, {
#                 onEachFeature: geo_json_022ed812a3bd6515854956159571d9de_onEachFeature,
#
#                 style: geo_json_022ed812a3bd6515854956159571d9de_styler,
#             ...{
# }
#         });
#
#         function geo_json_022ed812a3bd6515854956159571d9de_add (data) {
#             geo_json_022ed812a3bd6515854956159571d9de
#                 .addData(data);
#         }
#             geo_json_022ed812a3bd6515854956159571d9de_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-60.63064528767524, 3.829809372135571], [-60.335791005053586, 3.829809372135571], [-60.335791005053586, 4.039764468754662], [-60.63064528767524, 4.039764468754662], [-60.63064528767524, 3.829809372135571]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_022ed812a3bd6515854956159571d9de.addTo(map_1b8aa207e5709f68b88e6ef7ab68bf46);
#
#
#             var tile_layer_54e8381bb6f1c8785ac5b8cc521554b9 = L.tileLayer(
#                 &quot;https://gis.roycegeo.com/pgtitiler/searches/e1f9f3d794ac9669cf68e040e118cfbc/tiles/WebMercatorQuad/{z}/{x}/{y}?assets=visual&quot;,
#                 {
#   &quot;minZoom&quot;: 9,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 12,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Mosaic&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_54e8381bb6f1c8785ac5b8cc521554b9.addTo(map_1b8aa207e5709f68b88e6ef7ab68bf46);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Add Image Chip
#
# Use the Collections / Items path.
#
# gis.roycegeo.com/pgtitiler/collections/**Collection Name**/items/**Item ID**/bbox/**Bounding Box**/**HxW.File Format**/**Band Info**/assets=**Asset Name**/**Asset Band Info**

# %%
from IPython.display import Image
import IPython.display as Disp
image_url = "https://gis.roycegeo.com/pgtitiler/collections/royce-imagery/items/20240202_113458_SN29_RR_VISUAL_MS/bbox/37.372337,55.820437,37.391499,55.829923/256x256.png?bidx=1&bidx=2&bidx=3&assets=processed_image_0&asset_bidx=processed_image_0%7C1%2C2%2C3"
Image(url=image_url) 

#<img src=image_url>
# Out:
# <img src="https://gis.roycegeo.com/pgtitiler/collections/royce-imagery/items/20240202_113458_SN29_RR_VISUAL_MS/bbox/37.372337,55.820437,37.391499,55.829923/256x256.png?bidx=1&bidx=2&bidx=3&assets=processed_image_0&asset_bidx=processed_image_0%7C1%2C2%2C3"/>

# %% [markdown]
# ### WMTS Get Capabilities

# %%
response = httpx.get(
    f"{endpoint}/searches/e1f9f3d794ac9669cf68e040e118cfbc/WGS1984Quad/WMTSCapabilities.xml?tile_format=png&tile_scale=1&use_epsg=false&assets=visual"
)

print(response.text)
